# %%
import sqlite3

# Function to create the similarity_scores table
def create_similarity_table():
    conn = sqlite3.connect("analysis.db")
    cursor = conn.cursor()
    
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS similarity_scores (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            method TEXT NOT NULL,
            score REAL NOT NULL
        )
    """)
    
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS final_conclusion (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            conclusion TEXT NOT NULL
        )
    """)

    conn.commit()
    conn.close()
    print("✅ SQLite tables for similarity analysis created successfully!")

# Run the function
create_similarity_table()
# Out:
# ✅ SQLite tables for similarity analysis created successfully!

# %%
import sqlite3
def get_bible_text():
    conn = sqlite3.connect("bible.db")
    cursor = conn.cursor()
    
    cursor.execute("SELECT text FROM bible_verses")
    result = cursor.fetchall()
    
    conn.close()
    res = []
    for i in result:
        res.append(i[0])
    return res

#get_bible_text()

# %%
import sqlite3
def get_shakespeare_text():
    conn = sqlite3.connect("shakespeare.db")
    cursor = conn.cursor()
    
    cursor.execute("SELECT sentence FROM shakespeare_sentences")
    result = cursor.fetchall()
    
    conn.close()
    res = []
    for i in result:
        res.append(i[0])
    return res

# get_shakespeare_text()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def compute_tfidf_similarity(bible_texts, shakespeare_texts):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(bible_texts + shakespeare_texts)

    bible_tfidf = tfidf_matrix[:len(bible_texts)]
    shakespeare_tfidf = tfidf_matrix[len(bible_texts):]

    cosine_scores = []
    total = len(bible_texts)
    
    for i, (b, s) in enumerate(zip(bible_tfidf, shakespeare_tfidf), start=1):
        cosine_scores.append(cosine_similarity(b, s)[0][0])
        
        # Print progress every 1000 steps
        if i % 1000 == 0 or i == total:
            percent_done = (i / total) * 100
            print(f"🔄 TF-IDF Similarity: Processed {i}/{total} pairs ({percent_done:.2f}% done)")

    return sum(cosine_scores) / len(cosine_scores)

bible_texts = get_bible_text()
shakespeare_texts = get_shakespeare_text()

# Run
average_cosine_score = compute_tfidf_similarity(bible_texts, shakespeare_texts)
# Out:
# 🔄 TF-IDF Similarity: Processed 1000/31102 pairs (3.22% done)
# 🔄 TF-IDF Similarity: Processed 2000/31102 pairs (6.43% done)
# 🔄 TF-IDF Similarity: Processed 3000/31102 pairs (9.65% done)
# 🔄 TF-IDF Similarity: Processed 4000/31102 pairs (12.86% done)
# 🔄 TF-IDF Similarity: Processed 5000/31102 pairs (16.08% done)
# 🔄 TF-IDF Similarity: Processed 6000/31102 pairs (19.29% done)
# 🔄 TF-IDF Similarity: Processed 7000/31102 pairs (22.51% done)
# 🔄 TF-IDF Similarity: Processed 8000/31102 pairs (25.72% done)
# 🔄 TF-IDF Similarity: Processed 9000/31102 pairs (28.94% done)
# 🔄 TF-IDF Similarity: Processed 10000/31102 pairs (32.15% done)
# 🔄 TF-IDF Similarity: Processed 11000/31102 pairs (35.37% done)
# 🔄 TF-IDF Similarity: Processed 12000/31102 pairs (38.58% done)
# 🔄 TF-IDF Similarity: Processed 13000/31102 pairs (41.80% done)
# 🔄 TF-IDF Similarity: Processed 14000/31102 pairs (45.01% done)
# 🔄 TF-IDF Similarity: Processed 15000/31102 pairs (48.23% done)
# 🔄 TF-IDF Similarity: Processed 16000/31102 pairs (51.44% done)
# 🔄 TF-IDF Similarity: Processed 17000/31102 pairs (54.66% done)
# 🔄 TF-IDF Similarity: Processed 18000/31102 pairs (57.87% done)
# 🔄 TF-IDF Similarity: Processed 19000/31102 pairs (61.09% done)
# 🔄 TF-IDF Similarity: Processed 20000/31102 pairs (64.30% done)
# 🔄 TF-IDF Similarity: Processed 21000/31102 pairs (67.52% done)
# 🔄 TF-IDF Similarity: Processed 22000/31102 pairs (70.74% done)
# 🔄 TF-IDF Similarity: Processed 23000/31102 pairs (73.95% done)
# 🔄 TF-IDF Similarity: Processed 24000/31102 pairs (77.17% done)
# 🔄 TF-IDF Similarity: Processed 25000/31102 pairs (80.38% done)
# 🔄 TF-IDF Similarity: Processed 26000/31102 pairs (83.60% done)
# 🔄 TF-IDF Similarity: Processed 27000/31102 pairs (86.81% done)
# 🔄 TF-IDF Similarity: Processed 28000/31102 pairs (90.03% done)
# 🔄 TF-IDF Similarity: Processed 29000/31102 pairs (93.24% done)
# 🔄 TF-IDF Similarity: Processed 30000/31102 pairs (96.46% done)
# 🔄 TF-IDF Similarity: Processed 31000/31102 pairs (99.67% done)
# 🔄 TF-IDF Similarity: Processed 31102/31102 pairs (100.00% done)

# %%
print(f"📊 Average Cosine Similarity Score: {average_cosine_score:.4f}")
# Out:
# 📊 Average Cosine Similarity Score: 0.0238

# %%
from pymilvus import MilvusClient, DataType

CLUSTER_ENDPOINT = "http://localhost:19530"
TOKEN = "root:Milvus"

client = MilvusClient(
    uri=CLUSTER_ENDPOINT,
    token=TOKEN 
)

# %%
from pymilvus import connections, utility

# Connect to Milvus
connections.connect(alias="default", host="localhost", port="19530")

# List all collections
collections = utility.list_collections()
print(collections)

bible_collection = Collection("bible_verses")
shakespeare_collection = Collection("shakespeare_sentences")

# Get schema information
schema = bible_collection.schema

# Print field names
field_names = [field.name for field in schema.fields]
print("Fields in the collection:", field_names)

schema = shakespeare_collection.schema

# Print field names
field_names = [field.name for field in schema.fields]
print("Fields in the collection:", field_names)
# Out:
# ['customized_setup_2', 'customized_setup_3', 'customized_setup_4', 'quick_setup', 'bible_verses', 'shakespeare_sentences', 'customized_setup_1']
# Fields in the collection: ['id', 'ref', 'text', 'embedding']
# Fields in the collection: ['id', 'ref', 'sentence', 'embedding']

# %%
import ollama
import numpy as np

# Function to get   embeddings using Ollama (with error handling)
def get_embedding(text):
    try:
        embedding_data = ollama.embeddings(model="mxbai-embed-large", prompt=text)
        embedding_data = embedding_data["embedding"]  # Extract embedding
        embedding_data = np.array(embedding_data)
        return embedding_data
    except Exception as e:
        print(f"❌ Unexpected error generating embedding: {e}")
    return None  # Return None if an error occurs

# %%
import numpy as np
import sqlite3
from pymilvus import Collection
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from difflib import SequenceMatcher
import nltk
from nltk.util import ngrams

nltk.download('punkt')

# Load Bible & Shakespeare collections from Milvus
bible_collection = Collection("bible_verses")
shakespeare_collection = Collection("shakespeare_sentences")

# Load texts from both sources
bible_texts = get_bible_text()
shakespeare_texts = get_shakespeare_text()

# Compute TF-IDF Cosine Similarity
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(bible_texts + shakespeare_texts)

bible_tfidf = tfidf_matrix[:len(bible_texts)]
shakespeare_tfidf = tfidf_matrix[len(bible_texts):]

cosine_scores = cosine_similarity(bible_tfidf, shakespeare_tfidf)
average_cosine_score = np.mean(cosine_scores)

# Compute Jaccard Similarity
def jaccard_similarity(text1, text2):
    set1, set2 = set(text1.lower().split()), set(text2.lower().split())
    return len(set1 & set2) / len(set1 | set2)

jaccard_scores = [jaccard_similarity(b, s) for b, s in zip(bible_texts, shakespeare_texts)]
average_jaccard_score = np.mean(jaccard_scores)

# Compute N-Gram Overlap
def ngram_overlap(text1, text2, n=3):
    ngrams1, ngrams2 = set(ngrams(text1.split(), n)), set(ngrams(text2.split(), n))
    return len(ngrams1 & ngrams2) / max(len(ngrams1 | ngrams2), 1)

ngram_scores = [ngram_overlap(b, s) for b, s in zip(bible_texts, shakespeare_texts)]
average_ngram_score = np.mean(ngram_scores)

# Compute Levenshtein Distance Similarity
def levenshtein_similarity(text1, text2):
    return SequenceMatcher(None, text1, text2).ratio()

levenshtein_scores = [levenshtein_similarity(b, s) for b, s in zip(bible_texts, shakespeare_texts)]
average_levenshtein_score = np.mean(levenshtein_scores)

# Compute Vector Similarity using Milvus
def milvus_vector_similarity(text1, collection, field="text"):
    query_embedding = get_embedding(text1)
    search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
    results = collection.search(
        data=[query_embedding],
        anns_field="embedding",
        param=search_params,
        limit=5,
        output_fields=[field]
    )
    return np.mean([hit.distance for hit in results[0]])

vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
average_vector_score = np.mean(vector_scores)

# Aggregate all scores
scores = {
    "TF-IDF Cosine Similarity": average_cosine_score,
    "Jaccard Similarity": average_jaccard_score,
    "N-Gram Overlap": average_ngram_score,
    "Levenshtein Similarity": average_levenshtein_score,
    "Milvus Vector Similarity": average_vector_score
}

print("\n📊 **Aggregated Similarity Scores:**")
for method, score in scores.items():
    print(f"{method}: {score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to C:\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# 2025-03-09 23:01:23,368 [ERROR][handler]: RPC error: [search], <MilvusException: (code=101, message=failed to search: collection not loaded[collection=456493849065998355])>, <Time:{'RPC start': '2025-03-09 23:01:23.364301', 'RPC error': '2025-03-09 23:01:23.368323'}> (decorators.py:140)
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 66
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#
# Cell In[16], line 66, in <listcomp>(.0)
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#
# Cell In[16], line 57, in milvus_vector_similarity(text1, collection, field)
#      56 search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
# ---> 57 results = collection.search(
#      58     data=[query_embedding],
#      59     anns_field="embedding",
#      60     param=search_params,
#      61     limit=5,
#      62     output_fields=[field]
#      63 )
#      64 return np.mean([hit.distance for hit in results[0]])
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\orm\collection.py:799, in Collection.search(self, data, anns_field, param, limit, expr, partition_names, output_fields, timeout, round_decimal, **kwargs)
#     798 conn = self._get_connection()
# --> 799 resp = conn.search(
#     800     self._name,
#     801     data,
#     802     anns_field,
#     803     param,
#     804     limit,
#     805     expr,
#     806     partition_names,
#     807     output_fields,
#     808     round_decimal,
#     809     timeout=timeout,
#     810     schema=self._schema_dict,
#     811     **kwargs,
#     812 )
#     814 return SearchFuture(resp) if kwargs.get("_async", False) else resp
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:896, in GrpcHandler.search(self, collection_name, data, anns_field, param, limit, expression, partition_names, output_fields, round_decimal, timeout, **kwargs)
#     884 request = Prepare.search_requests_with_expr(
#     885     collection_name,
#     886     data,
#    (...)    894     **kwargs,
#     895 )
# --> 896 return self._execute_search(request, timeout, round_decimal=round_decimal, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:837, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     836     return SearchFuture(None, None, e)
# --> 837 raise e from e
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:826, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     825 response = self._stub.Search(request, timeout=timeout)
# --> 826 check_status(response.status)
#     827 round_decimal = kwargs.get("round_decimal", -1)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\utils.py:64, in check_status(status)
#      63 if status.code != 0 or status.error_code != 0:
# ---> 64     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=101, message=failed to search: collection not loaded[collection=456493849065998355])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[16], line 66
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#
# Cell In[16], line 66, in <listcomp>(.0)
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#
# Cell In[16], line 57, in milvus_vector_similarity(text1, collection, field)
#      56 search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
# ---> 57 results = collection.search(
#      58     data=[query_embedding],
#      59     anns_field="embedding",
#      60     param=search_params,
#      61     limit=5,
#      62     output_fields=[field]
#      63 )
#      64 return np.mean([hit.distance for hit in results[0]])
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\orm\collection.py:799, in Collection.search(self, data, anns_field, param, limit, expr, partition_names, output_fields, timeout, round_decimal, **kwargs)
#     798 conn = self._get_connection()
# --> 799 resp = conn.search(
#     800     self._name,
#     801     data,
#     802     anns_field,
#     803     param,
#     804     limit,
#     805     expr,
#     806     partition_names,
#     807     output_fields,
#     808     round_decimal,
#     809     timeout=timeout,
#     810     schema=self._schema_dict,
#     811     **kwargs,
#     812 )
#     814 return SearchFuture(resp) if kwargs.get("_async", False) else resp
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:896, in GrpcHandler.search(self, collection_name, data, anns_field, param, limit, expression, partition_names, output_fields, round_decimal, timeout, **kwargs)
#     884 request = Prepare.search_requests_with_expr(
#     885     collection_name,
#     886     data,
#    (...)    894     **kwargs,
#     895 )
# --> 896 return self._execute_search(request, timeout, round_decimal=round_decimal, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:837, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     836     return SearchFuture(None, None, e)
# --> 837 raise e from e
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:826, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     825 response = self._stub.Search(request, timeout=timeout)
# --> 826 check_status(response.status)
#     827 round_decimal = kwargs.get("round_decimal", -1)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\utils.py:64, in check_status(status)
#      63 if status.code != 0 or status.error_code != 0:
# ---> 64     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=101, message=failed to search: collection not loaded[collection=456493849065998355])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[16], line 66
#      57     results = collection.search(
#      58         data=[query_embedding],
#      59         anns_field="embedding",
#    (...)     62         output_fields=[field]
#      63     )
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#      69 # Aggregate all scores
#
# Cell In[16], line 66, in <listcomp>(.0)
#      57     results = collection.search(
#      58         data=[query_embedding],
#      59         anns_field="embedding",
#    (...)     62         output_fields=[field]
#      63     )
#      64     return np.mean([hit.distance for hit in results[0]])
# ---> 66 vector_scores = [milvus_vector_similarity(b, shakespeare_collection, "sentence") for b in bible_texts]
#      67 average_vector_score = np.mean(vector_scores)
#      69 # Aggregate all scores
#
# Cell In[16], line 57, in milvus_vector_similarity(text1, collection, field)
#      55 query_embedding = get_embedding(text1)
#      56 search_params = {"metric_type": "L2", "params": {"nprobe": 10}}
# ---> 57 results = collection.search(
#      58     data=[query_embedding],
#      59     anns_field="embedding",
#      60     param=search_params,
#      61     limit=5,
#      62     output_fields=[field]
#      63 )
#      64 return np.mean([hit.distance for hit in results[0]])
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\orm\collection.py:799, in Collection.search(self, data, anns_field, param, limit, expr, partition_names, output_fields, timeout, round_decimal, **kwargs)
#     796     return SearchFuture(None) if kwargs.get("_async", False) else resp
#     798 conn = self._get_connection()
# --> 799 resp = conn.search(
#     800     self._name,
#     801     data,
#     802     anns_field,
#     803     param,
#     804     limit,
#     805     expr,
#     806     partition_names,
#     807     output_fields,
#     808     round_decimal,
#     809     timeout=timeout,
#     810     schema=self._schema_dict,
#     811     **kwargs,
#     812 )
#     814 return SearchFuture(resp) if kwargs.get("_async", False) else resp
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#     143     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     135 try:
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     174 if req_id:
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     114         back_off = min(back_off * back_off_multiplier, max_back_off)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#     118     raise e from e
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      84 while True:
#      85     try:
# ---> 86         return func(*args, **kwargs)
#      87     except grpc.RpcError as e:
#      88         # Do not retry on these codes
#      89         if e.code() in IGNORE_RETRY_CODES:
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:896, in GrpcHandler.search(self, collection_name, data, anns_field, param, limit, expression, partition_names, output_fields, round_decimal, timeout, **kwargs)
#     873 check_pass_param(
#     874     limit=limit,
#     875     round_decimal=round_decimal,
#    (...)    881     timeout=timeout,
#     882 )
#     884 request = Prepare.search_requests_with_expr(
#     885     collection_name,
#     886     data,
#    (...)    894     **kwargs,
#     895 )
# --> 896 return self._execute_search(request, timeout, round_decimal=round_decimal, **kwargs)
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:837, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     835 if kwargs.get("_async", False):
#     836     return SearchFuture(None, None, e)
# --> 837 raise e from e
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\grpc_handler.py:826, in GrpcHandler._execute_search(self, request, timeout, **kwargs)
#     823     return SearchFuture(future, func)
#     825 response = self._stub.Search(request, timeout=timeout)
# --> 826 check_status(response.status)
#     827 round_decimal = kwargs.get("round_decimal", -1)
#     828 return SearchResult(
#     829     response.results,
#     830     round_decimal,
#     831     status=response.status,
#     832     session_ts=response.session_ts,
#     833 )
#
# File d:\projects\milvus-examples\venv\Lib\site-packages\pymilvus\client\utils.py:64, in check_status(status)
#      62 def check_status(status: Status):
#      63     if status.code != 0 or status.error_code != 0:
# ---> 64         raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=101, message=failed to search: collection not loaded[collection=456493849065998355])>
